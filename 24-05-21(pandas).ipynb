# %%
import pandas as pd

# %%
birds=pd.read_csv("birds.csv")
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
birds.head()     #five records from top
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
birds["huml"][4]
# Out:
# 62.8

# %% [markdown]
# ### indexing
# * iloc --> interger slicing
# * loc --> interger & non interger indices

# %%
birds.iloc[3]
# Out:
# id           3
# huml     77.65
# humw       5.7
# ulnal    65.76
# ulnaw     4.77
# feml     40.04
# femw      3.52
# tibl     69.17
# tibw       3.4
# tarl     35.78
# tarw      3.41
# type        SW
# Name: 3, dtype: object

# %%
birds.loc[3]
# Out:
# id           3
# huml     77.65
# humw       5.7
# ulnal    65.76
# ulnaw     4.77
# feml     40.04
# femw      3.52
# tibl     69.17
# tibw       3.4
# tarl     35.78
# tarw      3.41
# type        SW
# Name: 3, dtype: object

# %%
birds.sample(4)
# Out:
#       id   huml  humw   ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 231  231  42.46  3.49   47.34   3.27  36.03  2.94  49.17  2.68  34.38  2.25
# 333  333  20.80  1.95   23.44   1.60  20.67  1.45  35.52  1.45  25.41  1.36
# 167  167  80.00  4.70  111.96   4.87  40.17  3.34  68.89  3.25  33.69  2.70
# 2      2  79.97  6.37   69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
#
#     type
# 231    R
# 333   SO
# 167    W
# 2     SW

# %%
birds.shape
# Out:
# (420, 12)

# %%
birds.describe()
# Out:
#                id        huml        humw       ulnal       ulnaw        feml  \
# count  420.000000  419.000000  419.000000  417.000000  418.000000  418.000000
# mean   209.500000   64.650501    4.370573   69.115372    3.597249   36.872416
# std    121.387808   53.834549    2.854617   58.784775    2.186747   19.979082
# min      0.000000    9.850000    1.140000   14.090000    1.000000   11.830000
# 25%    104.750000   25.170000    2.190000   28.050000    1.870000   21.297500
# 50%    209.500000   44.180000    3.500000   43.710000    2.945000   31.130000
# 75%    314.250000   90.310000    5.810000   97.520000    4.770000   47.120000
# max    419.000000  420.000000   17.840000  422.000000   12.000000  117.070000
#
#              femw        tibl        tibw        tarl        tarw
# count  419.000000  418.000000  419.000000  419.000000  419.000000
# mean     3.220883   64.662823    3.182339   39.229976    2.930024
# std      2.023581   37.838145    2.080827   23.184313    2.185673
# ...

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      420 non-null    int64
#  1   huml    419 non-null    float64
#  2   humw    419 non-null    float64
#  3   ulnal   417 non-null    float64
#  4   ulnaw   418 non-null    float64
#  5   feml    418 non-null    float64
#  6   femw    419 non-null    float64
#  7   tibl    418 non-null    float64
#  8   tibw    419 non-null    float64
#  9   tarl    419 non-null    float64
#  10  tarw    419 non-null    float64
#  11  type    420 non-null    object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 39.5+ KB

# %%
birds.columns
# Out:
# Index(['id', 'huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw', 'type'],
#       dtype='object')

# %%
birds.index
# Out:
# RangeIndex(start=0, stop=420, step=1)

# %%
type(birds["id"])
# Out:
# pandas.core.series.Series

# %%
birds[["id"]]   #returns dataframes object
# Out:
#       id
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 415  415
# 416  416
# 417  417
# 418  418
# 419  419
#
# [420 rows x 1 columns]

# %%
birds[["id","huml","type"]]   #accessing subdataframes
# Out:
#       id   huml type
# 0      0  80.78   SW
# 1      1  88.91   SW
# 2      2  79.97   SW
# 3      3  77.65   SW
# 4      4  62.80   SW
# ..   ...    ...  ...
# 415  415  17.96   SO
# 416  416  19.21   SO
# 417  417  18.79   SO
# 418  418  20.38   SO
# 419  419  17.89   SO
#
# [420 rows x 3 columns]

# %%
birds[5:20:3]
# Out:
#     id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 5    5   61.92  4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07  2.83
# 8    8  118.20  7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62  4.37
# 11  11  186.00  9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80  4.59
# 14  14  149.19  6.98  121.48   6.21  43.33  5.39  155.00  6.61  75.65  3.36
# 17  17  124.53  6.01  100.37   5.82  34.54  5.43  145.00  7.12  65.92  3.28
#
#    type
# 5    SW
# 8    SW
# 11   SW
# 14   SW
# 17   SW

# %%
birds[5:7]
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 5   5  61.92  4.78  50.46   3.47  49.52  4.41  56.95  2.73  29.07  2.83   SW
# 6   6  79.73  5.94  67.39   4.50  42.07  3.41  71.26  3.56  37.22  3.64   SW

# %%
birds.iloc[20:100:20]   #start,stop,step
# Out:
#     id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 20  20  113.84   4.80  100.71   4.39  43.95  5.08  133.27  7.41  70.91  2.69
# 40  40  100.62   6.60  110.00   5.80  36.11  2.93   55.10  3.19  28.81  4.82
# 60  60  300.00  12.48  300.00   8.65  84.05  8.53  178.00  9.61  99.01  7.55
# 80  80   64.72   4.04   61.40   3.13  32.83  2.48   64.58  2.65  31.12  2.14
#
#    type
# 20   SW
# 40   SW
# 60   SW
# 80   SW

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
birds.loc[1,"ulnal"]
# Out:
# 80.53

# %%
birds.loc[100:120,["huml","humw"]]
# Out:
#        huml   humw
# 100   67.06   3.54
# 101   67.59   3.73
# 102  100.27   5.75
# 103   68.50   3.77
# 104   68.15   3.84
# 105  107.76   4.71
# 106  109.70   4.65
# 107  100.69   4.80
# 108  100.08   5.07
# 109   70.04   4.74
# 110   75.95   5.42
# 111  106.23   6.82
# 112  105.19   7.10
# 113   76.49   5.36
# 114   65.66   3.79
# 115   98.73   6.48
# 116  157.00   9.00
# 117  190.00  11.92
# 118   70.01   3.71
# 119   92.93   5.28
# 120  118.52   6.87

# %%
birds.loc[3,"huml"]=100

# %%
birds
# Out:
#       id    huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0   80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1   88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2   79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  100.00  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4   62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...     ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415   17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416   19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417   18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418   20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419   17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# ...

# %%
birds.loc[3,"huml"]=77.65

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %% [markdown]
# ### Features
#
# * label
# * columns

# %%
birds.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
birds.shape
# Out:
# (420, 12)

# %%
birds.shape[0]  #no of rows
# Out:
# 420

# %%
birds.shape[1]  #no of columns
# Out:
# 12

# %%
birds["type"]
# Out:
# 0      SW
# 1      SW
# 2      SW
# 3      SW
# 4      SW
#        ..
# 415    SO
# 416    SO
# 417    SO
# 418    SO
# 419    SO
# Name: type, Length: 420, dtype: object

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
birds[birds.columns[1:-2]]
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl
# 0    80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70
# 1    88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50
# 2    79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31
# 3    77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78
# 4    62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88
# ..     ...   ...    ...    ...    ...   ...    ...   ...    ...
# 415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99
# 416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60
# 417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86
# 418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98
# 419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69
#
# [420 rows x 9 columns]

# %%
birds["features_mean"]=birds[birds.columns[1:-2]].mean(axis=1)    #default it's 0

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type  features_mean
# 0     SW      28.676667
# ...

# %% [markdown]
# ### Filtering

# %%
birds.count()
# Out:
# id               420
# huml             419
# humw             419
# ulnal            417
# ulnaw            418
# feml             418
# femw             419
# tibl             418
# tibw             419
# tarl             419
# tarw             419
# type             420
# features_mean    420
# dtype: int64

# %%
birds["id"].max()   #maximum value of id
# Out:
# 419

# %%
birds["huml"].max()
# Out:
# 420.0

# %%
birds["huml"].min()
# Out:
# 9.85

# %%
birds["huml"]>90
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Name: huml, Length: 420, dtype: bool

# %%
birds[birds["huml"]>90]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# 12    12  172.00   8.44  142.00   8.43  52.18  6.68  180.00  9.62  82.58
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 246  246   90.13   5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55
# 247  247  100.29   6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03
# 248  248   96.46   5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95
# 249  249   93.37   5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30
# 250  250   99.69   6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23
#
#      tarw type  features_mean
# 8    4.37   SW      54.530000
# ...

# %%
birds[(birds["huml"]>90) & (birds["huml"]<150)]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 13    13  148.91   6.78  121.35   6.50  44.29  6.33  155.00  6.68  73.71
# 14    14  149.19   6.98  121.48   6.21  43.33  5.39  155.00  6.61  75.65
# 15    15  140.59   6.59  115.97   5.81  39.75  5.61  166.00  7.83  74.86
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 246  246   90.13   5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55
# 247  247  100.29   6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03
# 248  248   96.46   5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95
# 249  249   93.37   5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30
# 250  250   99.69   6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23
#
#      tarw type  features_mean
# 8    4.37   SW      54.530000
# ...

# %%
birds[birds["type"]=="P"]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %%
birds[birds["type"]=="SO"]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 292  292  29.61  2.41  33.93   2.02  30.79  2.19  51.64  2.01  37.33  1.78
# 293  293  30.28  2.89  35.37   2.15  31.09  2.51  53.36  2.31  39.52  1.69
# 294  294  28.10  2.44  32.50   2.19  29.68  2.33  50.47  2.21  37.98  1.79
# 295  295  28.66  2.48  33.24   2.02  29.33  2.26  50.64  2.05  35.99  1.85
# 296  296  36.36  3.31  40.51   2.56  37.52  2.85  53.96  2.63  42.71  2.41
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type  features_mean
# 292   SO      21.325556
# ...

# %%
birds[birds["type"]=="SO"].any(axis=1)   #or gate
# Out:
# 292    True
# 293    True
# 294    True
# 295    True
# 296    True
#        ...
# 415    True
# 416    True
# 417    True
# 418    True
# 419    True
# Length: 128, dtype: bool

# %%
birds[birds["type"]=="SO"].all(axis=1)   #and gate
# Out:
# 292    True
# 293    True
# 294    True
# 295    True
# 296    True
#        ...
# 415    True
# 416    True
# 417    True
# 418    True
# 419    True
# Length: 128, dtype: bool

# %%
birds[birds["huml"]>90].all(axis=1).sum()
# Out:
# 106

# %%
birds[birds["type"]=="SW"].all(axis=1).sum()
# Out:
# 115

# %%
birds[birds["type"]=="SW"].any(axis=1).sum()
# Out:
# 116

# %% [markdown]
# ### Statistics

# %%
birds.mean()
# Out:
# id               209.500000
# huml              64.650501
# humw               4.370573
# ulnal             69.115372
# ulnaw              3.597249
# feml              36.872416
# femw               3.220883
# tibl              64.662823
# tibw               3.182339
# tarl              39.229976
# tarw               2.930024
# features_mean     32.057554
# dtype: float64

# %%
birds["huml"].median()
# Out:
# 44.18

# %%
birds["huml"].sum()
# Out:
# 27088.56

# %%
birds[["huml","tarw"]].sum()
# Out:
# huml    27088.56
# tarw     1227.68
# dtype: float64

# %%
birds.describe()
# Out:
#                id        huml        humw       ulnal       ulnaw        feml  \
# count  420.000000  419.000000  419.000000  417.000000  418.000000  418.000000
# mean   209.500000   64.650501    4.370573   69.115372    3.597249   36.872416
# std    121.387808   53.834549    2.854617   58.784775    2.186747   19.979082
# min      0.000000    9.850000    1.140000   14.090000    1.000000   11.830000
# 25%    104.750000   25.170000    2.190000   28.050000    1.870000   21.297500
# 50%    209.500000   44.180000    3.500000   43.710000    2.945000   31.130000
# 75%    314.250000   90.310000    5.810000   97.520000    4.770000   47.120000
# max    419.000000  420.000000   17.840000  422.000000   12.000000  117.070000
#
#              femw        tibl        tibw        tarl        tarw  \
# count  419.000000  418.000000  419.000000  419.000000  419.000000
# mean     3.220883   64.662823    3.182339   39.229976    2.930024
# std      2.023581   37.838145    2.080827   23.184313    2.185673
# ...

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type  features_mean
# 0     SW      28.676667
# ...

# %%
birds["type"].value_counts()
# Out:
# SO    128
# SW    116
# W      65
# R      50
# P      38
# T      23
# Name: type, dtype: int64

# %%
birds["type"].mode()
# Out:
# 0    SO
# dtype: object

# %%
birds["huml"].mode()
# Out:
# 0    145.0
# dtype: float64

# %%
import numpy as np
birds["huml"].agg([np.mean,np.min,np.max])
# Out:
# mean     64.650501
# amin      9.850000
# amax    420.000000
# Name: huml, dtype: float64

# %%
birds["huml"].max()
# Out:
# 420.0

# %%
birds["huml"].argmax()
# Out:
# 58

# %%
birds["huml"].idxmax()  #huml max values index position
# Out:
# 58

# %%
birds["huml"].idxmin()
# Out:
# 264

# %%
birds["huml"].std()
# Out:
# 53.834548915405946

# %% [markdown]
# ### saving

# %%
data=birds.describe()

# %%
data
# Out:
#                id        huml        humw       ulnal       ulnaw        feml  \
# count  420.000000  419.000000  419.000000  417.000000  418.000000  418.000000
# mean   209.500000   64.650501    4.370573   69.115372    3.597249   36.872416
# std    121.387808   53.834549    2.854617   58.784775    2.186747   19.979082
# min      0.000000    9.850000    1.140000   14.090000    1.000000   11.830000
# 25%    104.750000   25.170000    2.190000   28.050000    1.870000   21.297500
# 50%    209.500000   44.180000    3.500000   43.710000    2.945000   31.130000
# 75%    314.250000   90.310000    5.810000   97.520000    4.770000   47.120000
# max    419.000000  420.000000   17.840000  422.000000   12.000000  117.070000
#
#              femw        tibl        tibw        tarl        tarw  \
# count  419.000000  418.000000  419.000000  419.000000  419.000000
# mean     3.220883   64.662823    3.182339   39.229976    2.930024
# std      2.023581   37.838145    2.080827   23.184313    2.185673
# ...

# %%
data.to_csv("birds_describe.csv")

# %% [markdown]
# ### Drop

# %%
birds.drop(["huml"],axis=1)
# Out:
#       id  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# 0      0  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1      1  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2      2  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3      3  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4      4  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
# ..   ...   ...    ...    ...    ...   ...    ...   ...    ...   ...  ...
# 415  415  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15   SO
# 416  416  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15   SO
# 417  417  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21   SO
# 418  418  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24   SO
# 419  419  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05   SO
#
#      features_mean
# 0        28.676667
# 1        39.914444
# 2        36.172222
# ...

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type  features_mean
# 0     SW      28.676667
# ...

# %%
birds.drop(["type","tarl"],axis=1)
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  1.05
#
#      features_mean
# 0        28.676667
# 1        39.914444
# 2        36.172222
# 3        33.976667
# 4        27.915556
# ..             ...
# ...

# %%
birds.drop(columns=["tarw","id"])
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl type  \
# 0    80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70   SW
# 1    88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50   SW
# 2    79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31   SW
# 3    77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78   SW
# 4    62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88   SW
# ..     ...   ...    ...    ...    ...   ...    ...   ...    ...  ...
# 415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99   SO
# 416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60   SO
# 417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86   SO
# 418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98   SO
# 419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69   SO
#
#      features_mean
# 0        28.676667
# 1        39.914444
# 2        36.172222
# 3        33.976667
# 4        27.915556
# ...

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type  features_mean
# 0     SW      28.676667
# ...

# %%
birds.drop(birds.columns[[0,4,2]],axis=1)
# Out:
#       huml  ulnal   feml  femw   tibl  tibw   tarl  tarw type  features_mean
# 0    80.78  72.01  41.81  3.70   5.50  4.03  38.70  3.84   SW      28.676667
# 1    88.91  80.53  47.04  4.30  80.22  4.51  41.50  4.01   SW      39.914444
# 2    79.97  69.26  43.07  3.90  75.35  4.04  38.31  3.34   SW      36.172222
# 3    77.65  65.76  40.04  3.52  69.17  3.40  35.78  3.41   SW      33.976667
# 4    62.80  52.09  33.95  2.72  56.27  2.96  31.88  3.13   SW      27.915556
# ..     ...    ...    ...   ...    ...   ...    ...   ...  ...            ...
# 415  17.96  19.25  18.36  1.54  31.25  1.33  21.99  1.15   SO      12.737778
# 416  19.21  20.76  19.24  1.45  33.21  1.28  23.60  1.15   SO      13.542222
# 417  18.79  19.83  20.96  1.43  34.45  1.41  22.86  1.21   SO      13.654444
# 418  20.38  22.53  21.35  1.48  36.09  1.53  25.98  1.24   SO      14.735556
# 419  17.89  19.26  17.62  1.34  29.81  1.24  21.69  1.05   SO      12.376667
#
# [420 rows x 10 columns]

# %%
df=pd.DataFrame([[1,2,3],[6,np.nan,7],[np.nan,np.nan,8]])
df
# Out:
#      0    1  2
# 0  1.0  2.0  3
# 1  6.0  NaN  7
# 2  NaN  NaN  8

# %%
df.isna()  #to know the missing values
# Out:
#        0      1      2
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df.isnull()
# Out:
#        0      1      2
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
# dropna  --> drops the rows where atleast 1 element is missing

df.dropna()
# Out:
#      0    1  2
# 0  1.0  2.0  3

# %%
df
# Out:
#      0    1  2
# 0  1.0  2.0  3
# 1  6.0  NaN  7
# 2  NaN  NaN  8

# %%
birds.set_index("type")   #setting index
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# type
# SW      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ...   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# SO    415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# SO    416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# SO    417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# SO    418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#       features_mean
# type
# SW        28.676667
# ...

# %%
birds.reset_index()
# Out:
#      index   id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  \
# 0        0    0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70
# 1        1    1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50
# 2        2    2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31
# 3        3    3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78
# 4        4    4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88
# ..     ...  ...    ...   ...    ...    ...    ...   ...    ...   ...    ...
# 415    415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99
# 416    416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60
# 417    417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86
# 418    418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98
# 419    419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69
#
#      tarw type  features_mean
# ...

# %%
# Out:
# id                     2
# huml               79.97
# humw                6.37
# ulnal              69.26
# ulnaw               5.28
# feml               43.07
# femw                 3.9
# tibl               75.35
# tibw                4.04
# tarl               38.31
# tarw                3.34
# type                  SW
# features_mean    36.1722
# Name: 2, dtype: object

# %%
df1=birds[birds["ulnal"]==144]
df1
# Out:
#       id   huml   humw  ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 9      9  145.0  10.42  144.0   7.05  70.96  7.44  120.00  7.31  78.67  6.34
# 154  154  129.5   7.52  144.0   6.40  60.31  4.91  113.44  5.15  70.11  3.57
#
#     type  features_mean
# 9     SW      65.650000
# 154    W      60.148889

# %%
birds.append(df1)    #add rows by using append
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 0      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70
# 1      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# 2      2   79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31
# 3      3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78
# 4      4   62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 417  417   18.79   1.63   19.83   1.53  20.96  1.43   34.45  1.41  22.86
# 418  418   20.38   1.78   22.53   1.50  21.35  1.48   36.09  1.53  25.98
# 419  419   17.89   1.44   19.26   1.10  17.62  1.34   29.81  1.24  21.69
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 154  154  129.50   7.52  144.00   6.40  60.31  4.91  113.44  5.15  70.11
#
#      tarw type  features_mean
# 0    3.84   SW      28.676667
# ...
